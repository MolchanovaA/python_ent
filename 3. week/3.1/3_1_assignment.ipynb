# %% [markdown]
# # Assignment 3.1
#
# > Replace all TODOs with your code.
# >
# > Do not change any other code and do not add/remove cells!

# %% [markdown]
# ## Scope

# %% [markdown]
# ### Task 1
#
# Make the program run without an error. You can only change the `calculate` function.

# %%
call_counter = 0


def calculate(a, b, base):
    # TODO
    return base + 1
    # return a ** (b / 2)


for _ in range(5):
    call_counter = calculate(5, 5, call_counter)

print(f'calculate called {call_counter} times') # should print "calculate called 5 times"
# Out:
# calculate called 5 times

# %% [markdown]
# ## Errors

# %% [markdown]
# ### Task 2
#
# Your task is to come up with an example for each error type. Replace all TODOs with a single-line expression that when evaluated will raise the specified error.

# %%
# a

a =

# should raise SyntaxError
# Out:
#   Cell In[30], line 3
#     a =
#        ^
# SyntaxError: invalid syntax

# %%
# b

b = int('l')

# should raise ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 3
#       1 # b
# ----> 3 b = int('l')
#       5 # should raise ValueError
#
# ValueError: invalid literal for int() with base 10: 'l'

# %%
# c

c = str(8)


# should raise NameError
# Out:
#   Cell In[36], line 3
#     $c = 8
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Tuples

# %% [markdown]
# ### Task 3
#
# Given a tuple `a1` create tuple `b1` which has all the elements of `a1` in reverse order.

# %%
a1 = (1, 2, 3, 4, 5)
b1 = a1[-1::-1]

print(b1)  # should print (5, 4, 3, 2, 1)
# Out:
# (5, 4, 3, 2, 1)

# %% [markdown]
# ### Task 4
#
# Write a function that will remove an element from tuple by index. It should create a new tuple.

# %%
def pop_element(v1: tuple, i: int) -> tuple:
    # TODO
    return v1[:i]+v1[i+1:]


print(pop_element((1,2,3), 1)) # should print (1, 3)
# Out:
# (1, 3)

# %% [markdown]
# ### Task 5
#
# Implement a function that will add vectors elemnt-wise in the same-dimentional space. If the dimensions of vectors do not match, raise ValueError with the appropriate message.

# %%
def add(v1: tuple, v2: tuple) -> tuple:
    # TODO
    sum_in_str = ''
    range_num = max(len(v1), len(v2))
    for x in range(range_num):
        num1, num2 = v1[x], v2[x]
        sum_in_str += str(num1 + num2) + '-'

    return tuple(sum_in_str.split('-'))[:-1:]

print(add((1,2,3), (4,5,6))) # should print (5, 7, 9)
print(add((1,2,3), (4,5,6,7))) # should raise error
# Out:
# 4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[66], line 13
#      10     return tuple(sum_in_str.split('-'))[:-1:]
#      12 # print(add((1,2,3), (4,5,6))) # should print (5, 7, 9)
# ---> 13 print(add((1,2,3), (4,5,6,7))) # should raise error
#
# Cell In[66], line 7, in add(v1, v2)
#       5 print(range_num)
#       6 for x in range(range_num):
# ----> 7     num1, num2 = v1[x], v2[x]
#       8     sum_in_str += str(num1 + num2) + '-'
#      10 return tuple(sum_in_str.split('-'))[:-1:]
#
# IndexError: tuple index out of range

# %% [markdown]
# ### Task 6
#
# Implement a [dot product](https://en.wikipedia.org/wiki/Dot_product) of two vectors.

# %%
def dot(v1: tuple, v2: tuple) -> tuple:
    sum = 0
    range_num = max(len(v1), len(v2))
    for x in range(range_num):
        num1, num2 = v1[x], v2[x]
        sum += num1 * num2
    return sum

print(dot((1,2,3), (4,5,6))) # should print 32
print(dot((1,2,3), (4,5,6,7))) # should raise error
# Out:
# 32
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[70], line 10
#       7     return sum
#       9 print(dot((1,2,3), (4,5,6))) # should print 32
# ---> 10 print(dot((1,2,3), (4,5,6,7))) # should raise error
#
# Cell In[70], line 5, in dot(v1, v2)
#       3 range_num = max(len(v1), len(v2))
#       4 for x in range(range_num):
# ----> 5     num1, num2 = v1[x], v2[x]
#       6     sum += num1 * num2
#       7 return sum
#
# IndexError: tuple index out of range
