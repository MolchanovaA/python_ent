# %% [markdown]
# # Assignment 8.2
#
# > Replace all TODOs with your code.
# >
# > Do not change any other code and do not add/remove cells!

# %% [markdown]
# ## Inheritance

# %% [markdown]
# ### Task 1
#
# Define a base class named `Account` to a general bank account.
#
# The class should include an initialization method (`__init__`), taking into account the number and holder name and methods for depositing money to the account and withdrawing from it. Do not forget to ensure that the account never has a negative balance.
#
# String representation (`__str__`) should be an abstract method (throw a corresponding error if it is called on the base `Account` class

# %%
import abc


class Account(abc.ABC):
    def __init__(self, number, name):
      self.number = number
      self.name = name
      self.balance = None
      
    def deposit(self, mount):
       if mount >= 0:
          self.balance = mount
       else:
          raise ValueError

    def withdraw(self, mount):
       if mount <= self.balance:
          self.balance -= mount
       else:
          raise ValueError
      
    @abc.abstractmethod
    def __str__(self):
      return ValueError

a = Account()
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 26
#      22     @abc.abstractmethod
#      23     def __str__(self):
#      24       return ValueError
# ---> 26 a = Account()
#      27 print(a)
#
# TypeError: Can't instantiate abstract class Account without an implementation for abstract method '__str__'

# %% [markdown]
# ### Task 2
#
# Derive a `CurrentAccount` subclass from the `Account` base class and provide its own implementation for the `__str__` method. The text representation should mention the type of account, account number, and remaining balance.

# %%
class CurrentAccount(Account):
    type = 'current'
    def __init__(self, number, name):
        super().__init__(number, name)
    
    def __str__(self):
        return f'name: {self.name}, acc_number: {self.number}, balance: {self.balance}, type: {self.type}'
    
b = CurrentAccount(333, 'test')
b.deposit(500)
b.withdraw(300)
print(b)
# Out:
# name: test, acc_number: 333, balance: 200, type: current

# %% [markdown]
# ### Task 3
#
# Derive a `SavingsAccount` subclass from the `Account` base class and provide its implementation for the `__str__` method. When initializing objects of this class, the caller must provide the `interest_rate` parameter.
#
#  The text representation should mention the type of account, interest rate, account number, and remaining balance.
#
# Provide additional method `add_interest` that adds interest based on `interest_rate`:
# $$new\_balance = old\_balance + old\_balance * interest\_rate$$

# %%
class SavingsAccount(Account):
    type = 'saving'
    def __init__(self, number, name, interest_rate):
        super().__init__(number, name)
        self.interest_rate = interest_rate

    def add_interest(self):
        self.balance += self.balance*self.interest_rate
    
    def __str__(self):
        return f'name: {self.name}, acc_number: {self.number}, balance: {self.balance}, type: {self.type}, int_rate: {self.interest_rate}'
    

    s = SavingsAccount(444, 's_name', 0.1)
    print(s)
    s.deposit(500)
    print(s, 'deposit')
    s.add_interest()
    print(s, 'added int')
# Out:
# name: s_name, acc_number: 444, balance: None, type: saving, int_rate: 0.1
# name: s_name, acc_number: 444, balance: 500, type: saving, int_rate: 0.1 deposit
# name: s_name, acc_number: 444, balance: 550.0, type: saving, int_rate: 0.1 added int

# %% [markdown]
# ### Task 4
#
# Create an array with different accounts, add/withdraw money from some of them, iterate over the array, and print the text representation of each.

# %%
accounts = []
cur = CurrentAccount(111, 'test_cur')
accounts.append(cur)
cur.deposit(1000)
cur.withdraw(900)

save_acc = SavingsAccount(222, 'test_save', 2)
accounts.append(save_acc)
save_acc.deposit(1000)
save_acc.add_interest()
save_acc.withdraw(3000)


for account in accounts:
    print(account)
# Out:
# name: test_save, acc_number: 222, balance: 1000, type: saving, int_rate: 2 BEFORE
# name: test_save, acc_number: 222, balance: 0, type: saving, int_rate: 2 SAVE
# name: test_cur, acc_number: 111, balance: 100, type: current
# name: test_save, acc_number: 222, balance: 0, type: saving, int_rate: 2
