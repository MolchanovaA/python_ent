# %% [markdown]
# # Assignment 7.1
#
# > Replace all TODOs with your code.
# >
# > Do not change any other code and do not add/remove cells!

# %%
# Do not edit this cell

from typing import List, Dict
import requests

# %% [markdown]
# ## Clients

# %% [markdown]
# ### Task 1
#
# Write a function that takes a GitHub repository name as input and uses the [GitHub Repository API](https://docs.github.com/en/rest/repos) to retrieve and return information about the specified repository, including:
#
# * Repository Name
# * Owner
# * Description
# * License (if available)
# * Creation Date
#
# Use the `requests` module for this task.

# %%
def get_repository_info(repo_name: str) -> Dict[str, str]:
    GITHUB_URL = f'https://api.github.com/repos/{repo_name}'
    resp_github = requests.get(GITHUB_URL)
    response_json = resp_github.json()
    result = {'repo_name': response_json['name'], 'owner': response_json['owner']['login'], 
              'descrioption':response_json['description'], 'created': response_json['created_at'], }
    try:
        result['license'] = response_json['license']
    except:
        print('no license')
    # print(result)
    return result
        

get_repository_info("octocat/Hello-World")
# Out:
# {'repo_name': 'Hello-World',
#  'owner': 'octocat',
#  'descrioption': 'My first repository on GitHub!',
#  'created': '2011-01-26T19:01:12Z',
#  'license': None}

# %% [markdown]
# ### Task 2
#
# Write a function that takes a GitHub repository name and uses the [GitHub Commits API](https://docs.github.com/en/rest/commits/commits) to retrieve and return information about the five most recent commits in a selected GitHub repository, including:
# * Commit Message
# * Author
# * Date
# * Link to the commit on GitHub
#
# Use the `requests` module for this task.

# %%
def get_recent_commits(repo_name: str) -> List[Dict[str, str]]:
    GITHIB_API_URL = f'https://api.github.com/repos/{repo_name}/commits'
    req = requests.get(GITHIB_API_URL)
    response = req.json()
    result_list = list()
    print(result_list, 'FIRST')
    for i, commit in enumerate(response):
        if i > 4:
            break
        commit_info = {
            'Commit Message': commit['commit']['message'],
            'Author' : commit['commit']['author']['name'],
            'Date': commit['commit']['committer']['date'],
            'Link to commit':  commit['commit']['url'],
        }
        result_list.append(commit_info)
    return result_list

get_recent_commits("octocat/hello-world")
# Out:
# [] FIRST
# [{'Commit Message': 'Merge pull request #6 from Spaceghost/patch-1\n\nNew line at end of file.',
#   'Author': 'The Octocat',
#   'Date': '2012-03-06T23:06:50Z',
#   'Link to commit': 'https://api.github.com/repos/octocat/Hello-World/git/commits/7fd1a60b01f91b314f59955a4e4d4e80d8edf11d'},
#  {'Commit Message': 'New line at end of file. --Signed off by Spaceghost',
#   'Author': 'Johnneylee Jack Rollins',
#   'Date': '2011-09-14T04:42:41Z',
#   'Link to commit': 'https://api.github.com/repos/octocat/Hello-World/git/commits/762941318ee16e59dabbacb1b4049eec22f0d303'},
#  {'Commit Message': 'first commit',
#   'Author': 'cameronmcefee',
#   'Date': '2011-01-26T19:06:08Z',
#   'Link to commit': 'https://api.github.com/repos/octocat/Hello-World/git/commits/553c2077f0edc3d5dc5d17262f6aa498e69d6f8e'}]
